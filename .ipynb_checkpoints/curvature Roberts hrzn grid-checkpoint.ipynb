# %%
import pandas as pd
import numpy as np
import scipy.linalg
import datetime
from numba import jit
from numba import autojit

# %%
path = 'c:/data'
gridfile='GridExport.csv'
hf=path + '\\' +gridfile
grid=pd.read_csv(hf)
grid.columns
# Out:
# Index(['Value', 'Row', 'Column'], dtype='object')

# %%
grid[0:10]
# Out:
#          Value  Row  Column
# 0  1248.295383    0       0
# 1  1248.055496    0       1
# 2  1247.742844    0       2
# 3  1247.296085    0       3
# 4  1246.913047    0       4
# 5  1246.784435    0       5
# 6  1246.836164    0       6
# 7  1246.973330    0       7
# 8  1247.041542    0       8
# 9  1246.927089    0       9

# %%
grid.shape
# Out:
# (37430, 3)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.scatter(grid['Row'][0:100],grid['Column'][0:100])

# %%
plt.figure(figsize=(8,8))
plt.scatter(x=grid['Column'],y=grid['Row'],c=grid['Value'],cmap='Accent')

# %%
grid[['Column']=0,['Row']=0]
# Out:
#   File "<ipython-input-8-d397302174fd>", line 1
#     grid[['Column']=0,['Row']=0]
#                    ^
# SyntaxError: invalid syntax

# %%
grid.shape
# Out:
# (37430, 3)

# %%
Z = np.array(grid['Value'])
Z=img.reshape(190,197)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-923c4edc6ab0> in <module>()
#       1 Z = np.array(grid['Value'])
# ----> 2 Z=img.reshape(190,197)
#       3
#
# NameError: name 'img' is not defined

# %%
Z.shape
# Out:
# (37430,)

# %%
plt.imshow(Z, cmap='Accent')
plt.ylim(min(plt.ylim()), max(plt.ylim()))
#plt.xlim(max(plt.xlim()), min(plt.xlim()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-665494074a54> in <module>()
# ----> 1 plt.imshow(Z, cmap='Accent')
#       2 plt.ylim(min(plt.ylim()), max(plt.ylim()))
#       3 #plt.xlim(max(plt.xlim()), min(plt.xlim()))
#
# C:\Users\dkon9\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3155                         filternorm=filternorm, filterrad=filterrad,
#    3156                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3157                         **kwargs)
#    3158     finally:
#    3159         ax._hold = washold
#
# C:\Users\dkon9\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# C:\Users\dkon9\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5122                               resample=resample, **kwargs)
#    5123
# -> 5124         im.set_data(X)
#    5125         im.set_alpha(alpha)
#    5126         if im.get_clip_path() is None:
#
# C:\Users\dkon9\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     598         if (self._A.ndim not in (2, 3) or
#     599                 (self._A.ndim == 3 and self._A.shape[-1] not in (3, 4))):
# --> 600             raise TypeError("Invalid dimensions for image data")
#     601
#     602         self._imcache = None
#
# TypeError: Invalid dimensions for image data

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.gca(projection='3d')
#ax.plot_surface(X, Y, Z, rstride=1, cstride=1, alpha=0.2)
ax.scatter(grid['Column'],grid['Row'],grid['Value'], cmap= 'Accent', s=50)
plt.xlabel('X')
plt.ylabel('Y')
ax.set_zlabel('Z')

# %%
i=0

data=np.zeros((9,3))
for x in range(0,3):
    for y in range (0,3):
        #data=np.append(data,[x,y,Z[x,y]])
        data[i]=[x,y,Z[x,y]]
        i+=1
        
data
#data=  Z[x-1:x+2,y-1:y+2]
#data =
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-79b63e5a54e8> in <module>()
#       5     for y in range (0,3):
#       6         #data=np.append(data,[x,y,Z[x,y]])
# ----> 7         data[i]=[x,y,Z[x,y]]
#       8         i+=1
#       9
#
# IndexError: too many indices for array

# %%
A = np.c_[np.ones(data.shape[0]), data[:,:2], np.prod(data[:,:2], axis=1), data[:,:2]**2]
C,_,_,_ = scipy.linalg.lstsq(A, data[:,2])
C[:10]
# Out:
# array([ 0.,  0.,  0.,  0.,  0.,  0.])

# %%
 # from Curvature Attributes and their Application in 3D Interpreted Horizons. Roberts 

f,d,e,c,a,b = C

# %%
dip_rad = np.arctan(np.sqrt(d**2+e**2))
dip_ang = 180*dip_rad/np.pi
dip_ang
# Out:
# 0.0

# %%
# K== curvature
Kmean = (a*(1+e**2)-c*d*e+b*(1+d**2))/(1+d**2+e**2)**(3/2)
Kmean
# Out:
# 0.0

# %%
Kgaus=(4*a*b-c**2)/(1+d**2+e**2)**2
Kgaus
# Out:
# 0.0

# %%
Kmax = Kmean + (Kmean**2-Kgaus)**.5
Kmax
# Out:
# 0.0

# %%
Kmin = Kmean - (Kmean**2-Kgaus)**.5
Kmin
# Out:
# 0.0

# %%
Kplus = (a+b)+((a-b)**2+c**2)**.5
Kplus
# Out:
# 0.0

# %%
Kminus = (a+b)-((a-b)**2+c**2)**.5
Kminus
# Out:
# 0.0

# %%
#Shape Index
Si=2/np.pi*np.arctan((Kmin+Kmax)/(Kmax-Kmin))
Si
# Out:
# C:\Users\dkon9\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   from ipykernel import kernelapp as app
# nan

# %%
#Dip Curvature
Kd=2*(a*e**2-c*d*e+b*d**2)/((d**2+e**2)*(1+d**2+e**2)**.5)
Kd
# Out:
# C:\Users\dkon9\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   from ipykernel import kernelapp as app
# nan

# %%
#Strike Curvature
Ks=
# Out:
#   File "<ipython-input-26-f1bd95c7c6a4>", line 2
#     Ks=
#        ^
# SyntaxError: invalid syntax

# %%
Colmax,Rowmax=Z.shape
print(Colmax,Rowmax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-4bd33471429f> in <module>()
#       1
# ----> 2 Colmax,Rowmax=Z.shape
#       3 print(Colmax,Rowmax)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
Colmax,Rowmax=Z.shape
data=np.zeros((81,3))
Kmean=np.zeros(Z.shape)
Kgaus=np.zeros(Z.shape)
Kmax=np.zeros(Z.shape)
Kmin=np.zeros(Z.shape)
Kplus=np.zeros(Z.shape)
Kminus=np.zeros(Z.shape)
Si=np.zeros(Z.shape)

ti=datetime.datetime.now()
@autojit
def runK():
    for ci in range(4,Colmax-7):
        for ri in range(4,Rowmax-7):
            i=0
            for xs in range(0,9):   #xs range to cacl surface
                x=xs+ci-1           
                for ys in range (0,9):
                    y=ys+ri-1
                    #print(x,y)
                    data[i]=[xs,ys,Z[x,y]]
                    i+=1

            A = np.c_[np.ones(data.shape[0]), data[:,:2], np.prod(data[:,:2], axis=1), data[:,:2]**2]
            C,_,_,_ = scipy.linalg.lstsq(A, data[:,2])
            f,d,e,c,a,b = C
            Kmean[ci,ri] = (a*(1+e**2)-c*d*e+b*(1+d**2))/(1+d**2+e**2)**(3/2)
            Kgaus[ci,ri]=(4*a*b-c**2)/(1+d**2+e**2)**2
            Kmax[ci,ri] = Kmean[ci,ri] + (Kmean[ci,ri]**2-Kgaus[ci,ri])**.5
            Kmin[ci,ri] = Kmean[ci,ri] - (Kmean[ci,ri]**2-Kgaus[ci,ri])**.5
            Kplus[ci,ri] = (a+b)+((a-b)**2+c**2)**.5
            Kminus[ci,ri] = (a+b)-((a-b)**2+c**2)**.5
            Si[ci,ri]=2/np.pi*np.arctan((Kmin[ci,ri]+Kmax[ci,ri])/(Kmax[ci,ri]-Kmin[ci,ri]))

runK()
tstop=datetime.datetime.now()
trun = tstop-ti
print(trun)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-18ad8782d1b3> in <module>()
# ----> 1 Colmax,Rowmax=Z.shape
#       2 data=np.zeros((81,3))
#       3 Kmean=np.zeros(Z.shape)
#       4 Kgaus=np.zeros(Z.shape)
#       5 Kmax=np.zeros(Z.shape)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
Kmean[0,0]=5
Kmean[0,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-864ad9f0374b> in <module>()
# ----> 1 Kmean[0,0]=5
#       2 Kmean[0,0]
#
# TypeError: 'numpy.float64' object does not support item assignment

# %%
ti-tstop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-927aba777eeb> in <module>()
# ----> 1 ti-tstop
#
# NameError: name 'ti' is not defined

# %%
plt.figure(1)
plt.imshow(Kmean, cmap='afmhot')
plt.ylim(min(plt.ylim()), max(plt.ylim()))

plt.figure(2)
plt.imshow(Z, cmap='Accent')
plt.ylim(min(plt.ylim()), max(plt.ylim()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-2d5b95ea0a46> in <module>()
#       1 plt.figure(1)
# ----> 2 plt.imshow(Kmean, cmap='afmhot')
#       3 plt.ylim(min(plt.ylim()), max(plt.ylim()))
#       4
#       5 plt.figure(2)
#
# C:\Users\dkon9\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3155                         filternorm=filternorm, filterrad=filterrad,
#    3156                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3157                         **kwargs)
#    3158     finally:
#    3159         ax._hold = washold
#
# C:\Users\dkon9\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# C:\Users\dkon9\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5122                               resample=resample, **kwargs)
#    5123
# -> 5124         im.set_data(X)
#    5125         im.set_alpha(alpha)
#    5126         if im.get_clip_path() is None:
#
# C:\Users\dkon9\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     598         if (self._A.ndim not in (2, 3) or
#     599                 (self._A.ndim == 3 and self._A.shape[-1] not in (3, 4))):
# --> 600             raise TypeError("Invalid dimensions for image data")
#     601
#     602         self._imcache = None
#
# TypeError: Invalid dimensions for image data
